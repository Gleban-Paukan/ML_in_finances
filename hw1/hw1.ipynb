# %% [markdown]
# ### Let's download the Data

# %%
import os
import time
from datetime import datetime

import numpy as np
import scipy
import yfinance as yf

# %%
COMPANY_TICKERS = {
    "3i": "III",
    "Admiral Group": "ADM",
    "Airtel Africa": "AAF",
    "Alliance Witan": "ALW",
    "Anglo American plc": "AAL",
    "Antofagasta plc": "ANTO",
    "Ashtead Group": "AHT",
    "Associated British Foods": "ABF",
    "AstraZeneca": "AZN",
    "Auto Trader Group": "AUTO",
    "Aviva": "AV",
    "Babcock International": "BAB",
    "BAE Systems": "BA",
    "Barclays": "BARC",
    "Barratt Redrow": "BTRW",
    "Beazley": "BEZ",
    "Berkeley Group Holdings": "BKG",
    "BP": "BP",
    "British American Tobacco": "BATS",
    "BT Group": "BT-A",
    "Bunzl": "BNZL",
    "Burberry Group": "BRBY",
    "Centrica": "CNA",
    "Coca-Cola Europacific Partners": "CCEP",
    "Coca-Cola HBC": "CCH",
    "Compass Group": "CPG",
    "Convatec": "CTEC",
    "Croda International": "CRDA",
    "DCC plc": "DCC",
    "Diageo": "DGE",
    "Diploma": "DPLM",
    "Endeavour Mining": "EDV",
    "Entain": "ENT",
    "EasyJet": "EZJ",
    "Experian": "EXPN",
    "F & C Investment Trust": "FCIT",
    "Fresnillo plc": "FRES",
    "Games Workshop": "GAW",
    "Glencore": "GLEN",
    "GSK plc": "GSK",
    "Haleon": "HLN",
    "Halma plc": "HLMA",
    "Hikma Pharmaceuticals": "HIK",
    "Hiscox": "HSX",
    "Howdens Joinery": "HWDN",
    "HSBC": "HSBA",
    "ICG": "ICG",
    "IHG Hotels & Resorts": "IHG",
    "IMI": "IMI",
    "Imperial Brands": "IMB",
    "Informa": "INF",
    "International Airlines Group": "IAG",
    "Intertek": "ITRK",
    "JD Sports": "JD",
    "Kingfisher plc": "KGF",
    "Land Securities": "LAND",
    "Legal & General": "LGEN",
    "Lloyds Banking Group": "LLOY",
    "LondonMetric Property": "LMP",
    "London Stock Exchange Group": "LSEG",
    "M&G": "MNG",
    "Marks & Spencer": "MKS",
    "Melrose Industries": "MRO",
    "Metlen Energy & Metals": "MTLN",
    "Mondi": "MNDI",
    "National Grid plc": "NG",
    "NatWest Group": "NWG",
    "Next plc": "NXT",
    "Pearson plc": "PSON",
    "Pershing Square Holdings": "PSH",
    "Persimmon": "PSN",
    "Phoenix Group": "PHNX",
    "Polar Capital Technology Trust": "PCT",
    "Prudential plc": "PRU",
    "Reckitt": "RKT",
    "RELX": "REL",
    "Rentokil Initial": "RTO",
    "Rightmove": "RMV",
    "Rio Tinto": "RIO",
    "Rolls-Royce Holdings": "RR",
    "Sage Group": "SGE",
    "Sainsbury's": "SBRY",
    "Schroders": "SDR",
    "Scottish Mortgage Investment Trust": "SMT",
    "Segro": "SGRO",
    "Severn Trent": "SVT",
    "Shell plc": "SHEL",
    "Smiths Group": "SMIN",
    "Smith & Nephew": "SN",
    "Spirax Group": "SPX",
    "SSE plc": "SSE",
    "Standard Chartered": "STAN",
    "St. James's Place": "STJ",
    "Tesco": "TSCO",
    "Unilever": "ULVR",
    "United Utilities": "UU",
    "Vodafone Group": "VOD",
    "Weir Group": "WEIR",
    "Whitbread": "WTB",
    "WPP": "WPP",
}

yahoo_symbols = {}
for name, t in COMPANY_TICKERS.items():
    yf_ticker = t.replace("-", ".") + ".L"
    yahoo_symbols[name] = yf_ticker

# 3. Папка для сохранения
DATA_DIR = "assets_data"
os.makedirs(DATA_DIR, exist_ok=True)

# 4. Параметры периода (можно менять под себя)
START_DATE = "2000-01-01"  # или любой другой
END_DATE = datetime.today().strftime("%Y-%m-%d")
INTERVAL = "1wk"  # недельные данные

# 5. Загрузка и сохранение
for company, ticker in yahoo_symbols.items():
    print(f"Downloading {company} ({ticker})...")
    try:
        data = yf.download(
            ticker,
            start=START_DATE,
            end=END_DATE,
            interval=INTERVAL,
            progress=False,
        )
        if data.empty:
            print(f"  Warning: no data for {ticker}")
            continue

        # имя файла: TICKER.csv (без суффикса .L в имени, опционально)
        base_ticker = ticker.replace(".L", "")
        file_path = os.path.join(DATA_DIR, f"{base_ticker}.csv")
        data.to_csv(file_path)
        print(f"  Saved to {file_path}")
        time.sleep(0.2)  # лёгкий sleep, чтобы не спамить запросами
    except Exception as e:
        print(f"  Error for {ticker}: {e}")

INDEX_TICKER = "^FTSE"

print(f"Downloading index FTSE 100 ({INDEX_TICKER})...")
idx = yf.download(
    INDEX_TICKER,
    start=START_DATE,
    end=END_DATE,
    interval=INTERVAL,
    progress=False,
)

if not idx.empty:
    index_path = os.path.join(DATA_DIR, "FTSE_INDEX.csv")
    idx.to_csv(index_path)
    print(f"  Saved index to {index_path}")
else:
    print("  Warning: no data for index")
# Out:
# Downloading 3i (III.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/III.csv
# Downloading Admiral Group (ADM.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/ADM.csv
# Downloading Airtel Africa (AAF.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/AAF.csv
# Downloading Alliance Witan (ALW.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/ALW.csv
# Downloading Anglo American plc (AAL.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/AAL.csv
# Downloading Antofagasta plc (ANTO.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/ANTO.csv
# Downloading Ashtead Group (AHT.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/AHT.csv
# Downloading Associated British Foods (ABF.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/ABF.csv
# Downloading AstraZeneca (AZN.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/AZN.csv
# Downloading Auto Trader Group (AUTO.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/AUTO.csv
# Downloading Aviva (AV.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/AV.csv
# Downloading Babcock International (BAB.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/BAB.csv
# Downloading BAE Systems (BA.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/BA.csv
# Downloading Barclays (BARC.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/BARC.csv
# Downloading Barratt Redrow (BTRW.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/BTRW.csv
# Downloading Beazley (BEZ.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/BEZ.csv
# Downloading Berkeley Group Holdings (BKG.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/BKG.csv
# Downloading BP (BP.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/BP.csv
# Downloading British American Tobacco (BATS.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/BATS.csv
# Downloading BT Group (BT.A.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#
# 1 Failed download:
# ['BT.A.L']: YFTzMissingError('possibly delisted; no timezone found')
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Warning: no data for BT.A.L
# Downloading Bunzl (BNZL.L)...
#   Saved to assets_data/BNZL.csv
# Downloading Burberry Group (BRBY.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/BRBY.csv
# Downloading Centrica (CNA.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/CNA.csv
# Downloading Coca-Cola Europacific Partners (CCEP.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/CCEP.csv
# Downloading Coca-Cola HBC (CCH.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/CCH.csv
# Downloading Compass Group (CPG.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/CPG.csv
# Downloading Convatec (CTEC.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/CTEC.csv
# Downloading Croda International (CRDA.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/CRDA.csv
# Downloading DCC plc (DCC.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/DCC.csv
# Downloading Diageo (DGE.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/DGE.csv
# Downloading Diploma (DPLM.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/DPLM.csv
# Downloading Endeavour Mining (EDV.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/EDV.csv
# Downloading Entain (ENT.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/ENT.csv
# Downloading EasyJet (EZJ.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/EZJ.csv
# Downloading Experian (EXPN.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/EXPN.csv
# Downloading F & C Investment Trust (FCIT.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/FCIT.csv
# Downloading Fresnillo plc (FRES.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/FRES.csv
# Downloading Games Workshop (GAW.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/GAW.csv
# Downloading Glencore (GLEN.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/GLEN.csv
# Downloading GSK plc (GSK.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/GSK.csv
# Downloading Haleon (HLN.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/HLN.csv
# Downloading Halma plc (HLMA.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/HLMA.csv
# Downloading Hikma Pharmaceuticals (HIK.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/HIK.csv
# Downloading Hiscox (HSX.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/HSX.csv
# Downloading Howdens Joinery (HWDN.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/HWDN.csv
# Downloading HSBC (HSBA.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/HSBA.csv
# Downloading ICG (ICG.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/ICG.csv
# Downloading IHG Hotels & Resorts (IHG.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/IHG.csv
# Downloading IMI (IMI.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/IMI.csv
# Downloading Imperial Brands (IMB.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/IMB.csv
# Downloading Informa (INF.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/INF.csv
# Downloading International Airlines Group (IAG.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/IAG.csv
# Downloading Intertek (ITRK.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/ITRK.csv
# Downloading JD Sports (JD.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/JD.csv
# Downloading Kingfisher plc (KGF.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/KGF.csv
# Downloading Land Securities (LAND.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/LAND.csv
# Downloading Legal & General (LGEN.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/LGEN.csv
# Downloading Lloyds Banking Group (LLOY.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/LLOY.csv
# Downloading LondonMetric Property (LMP.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/LMP.csv
# Downloading London Stock Exchange Group (LSEG.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/LSEG.csv
# Downloading M&G (MNG.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/MNG.csv
# Downloading Marks & Spencer (MKS.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/MKS.csv
# Downloading Melrose Industries (MRO.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/MRO.csv
# Downloading Metlen Energy & Metals (MTLN.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/MTLN.csv
# Downloading Mondi (MNDI.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/MNDI.csv
# Downloading National Grid plc (NG.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/NG.csv
# Downloading NatWest Group (NWG.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/NWG.csv
# Downloading Next plc (NXT.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/NXT.csv
# Downloading Pearson plc (PSON.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/PSON.csv
# Downloading Pershing Square Holdings (PSH.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/PSH.csv
# Downloading Persimmon (PSN.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/PSN.csv
# Downloading Phoenix Group (PHNX.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/PHNX.csv
# Downloading Polar Capital Technology Trust (PCT.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/PCT.csv
# Downloading Prudential plc (PRU.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/PRU.csv
# Downloading Reckitt (RKT.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/RKT.csv
# Downloading RELX (REL.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/REL.csv
# Downloading Rentokil Initial (RTO.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/RTO.csv
# Downloading Rightmove (RMV.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/RMV.csv
# Downloading Rio Tinto (RIO.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/RIO.csv
# Downloading Rolls-Royce Holdings (RR.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/RR.csv
# Downloading Sage Group (SGE.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/SGE.csv
# Downloading Sainsbury's (SBRY.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/SBRY.csv
# Downloading Schroders (SDR.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/SDR.csv
# Downloading Scottish Mortgage Investment Trust (SMT.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/SMT.csv
# Downloading Segro (SGRO.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/SGRO.csv
# Downloading Severn Trent (SVT.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/SVT.csv
# Downloading Shell plc (SHEL.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/SHEL.csv
# Downloading Smiths Group (SMIN.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/SMIN.csv
# Downloading Smith & Nephew (SN.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#
# 1 Failed download:
# ['SN.L']: Timeout('Failed to perform, curl: (28) Connection timed out after 10000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Warning: no data for SN.L
# Downloading Spirax Group (SPX.L)...
#   Saved to assets_data/SPX.csv
# Downloading SSE plc (SSE.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/SSE.csv
# Downloading Standard Chartered (STAN.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/STAN.csv
# Downloading St. James's Place (STJ.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/STJ.csv
# Downloading Tesco (TSCO.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#
# 1 Failed download:
# ['TSCO.L']: Timeout('Failed to perform, curl: (28) Connection timed out after 10000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Warning: no data for TSCO.L
# Downloading Unilever (ULVR.L)...
# 1 Failed download:
# ['ULVR.L']: Timeout('Failed to perform, curl: (28) Connection timed out after 10000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Warning: no data for ULVR.L
# Downloading United Utilities (UU.L)...
#   Saved to assets_data/UU.csv
# Downloading Vodafone Group (VOD.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/VOD.csv
# Downloading Weir Group (WEIR.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Saved to assets_data/WEIR.csv
# Downloading Whitbread (WTB.L)...
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#
# 1 Failed download:
# ['WTB.L']: Timeout('Failed to perform, curl: (28) Connection timed out after 10000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# /tmp/ipykernel_974/91252085.py:129: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
#   Warning: no data for WTB.L
# Downloading WPP (WPP.L)...
# 1 Failed download:
# ['WPP.L']: Timeout('Failed to perform, curl: (28) Connection timed out after 10000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# /tmp/ipykernel_974/91252085.py:153: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   idx = yf.download(
#   Warning: no data for WPP.L
# Downloading index FTSE 100 (^FTSE)...
#   Saved index to assets_data/FTSE_INDEX.csv

# %%
import os
import pandas as pd
import yfinance as yf

DATA_DIR = "assets_data"

def load_assets_returns_from_custom_csv(data_dir=DATA_DIR):
    all_rets = []

    for fname in os.listdir(data_dir):
        if not fname.lower().endswith(".csv"):
            continue

        path = os.path.join(data_dir, fname)
        df_raw = pd.read_csv(path, header=None)

        col_names = df_raw.iloc[0].tolist()
        df = df_raw.iloc[1:].copy()
        df.columns = col_names

        ticker = str(df.iloc[0]["Close"]).strip()

        df = df.iloc[2:].copy()

        df["Date"] = pd.to_datetime(df["Price"], errors="coerce")
        df = df.dropna(subset=["Date"])
        df = df.set_index("Date").sort_index()

        price = pd.to_numeric(df["Close"], errors="coerce").dropna()

        ret = price.pct_change().rename(ticker.replace(".L", ""))
        all_rets.append(ret)

    R = pd.concat(all_rets, axis=1)
    R = R.dropna(how="all")
    return R


R_assets = load_assets_returns_from_custom_csv(DATA_DIR)
if '^FTSE' in R_assets.columns:
    R_assets = R_assets.drop(columns=['^FTSE'])

def load_index_returns(start=None, end=None, interval="1wk"):
    idx = yf.download(
        "^FTSE",
        start=start,
        end=end,
        interval=interval,
        progress=False,
    )

    if idx.empty:
        raise ValueError("Не удалось скачать данные по индексу FTSE 100")

    if isinstance(idx, pd.DataFrame):
        if "Adj Close" in idx.columns:
            col = "Adj Close"
        else:
            col = "Close"
        s = idx[col]
    else:
        s = idx

    s = pd.Series(s.values[:, 0], index=idx.index, name="price_ftse")

    r_b = s.pct_change()
    r_b.name = "FTSE100"
    r_b = r_b.dropna()
    return r_b


start_date = R_assets.index.min()
end_date = R_assets.index.max()
R_B = load_index_returns(start=start_date, end=end_date, interval="1wk")


R_assets = R_assets.resample('W-FRI').last()
R_B = R_B.resample('W-FRI').last()

common_idx = R_assets.index.intersection(R_B.index)

R_assets = R_assets.loc[common_idx].sort_index()
R_B = R_B.loc[common_idx].sort_index()

R_assets = R_assets.dropna(axis=1, thresh=int(0.8 * len(R_assets)))

R_assets = R_assets.fillna(0.0)
R_B = R_B.fillna(0.0)

R_B_centered = R_B - R_B.mean()
R_assets_centered = R_assets - R_assets.mean(axis=0)

X = R_assets_centered.values
y = R_B_centered.values

print("R_assets shape:", R_assets.shape)
print("R_B shape:", R_B.shape)
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# R_assets shape: (1349, 81)
# R_B shape: (1349,)
# X shape: (1349, 81)
# y shape: (1349,)
# C:\Users\Gleba\AppData\Local\Temp\ipykernel_10232\391636173.py:44: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   idx = yf.download(

# %%
train_to_test_ratio = 0.8
n_dates = X.shape[0]
A_train = np.array(X)[:int(n_dates * train_to_test_ratio), :]
b_train = np.array(y)[:int(n_dates * train_to_test_ratio)]

A_test = np.array(X)[int(n_dates * train_to_test_ratio):, :]
b_test = np.array(y)[int(n_dates * train_to_test_ratio):]

# %%
n = A_train.shape[0]
d_train = A_train.shape[1]
eigenvalues_a_train = np.linalg.eigvalsh(A_train @ A_train.T)
L = np.max(eigenvalues_a_train) / (4 * n)

# %%
def sigmoid(x):
    """
    Вычисляет сигмоидную функцию.

    Параметры:
        x (np.array): Входное значение.

    Возвращает:
        sigmoid (np.array) Значение сигмоидной функции для входных данных.
    """
    return scipy.special.expit(x)


def loss(x, A=A_train, b=b_train, lambda_value=L / 1000):
    """
    Вычисляет значение функции потерь.

    Параметры:
        x (np.array): Вектор параметров модели.
        A (np.array): Матрица признаков обучающей выборки.
        b (np.array): Вектор меток обучающей выборки.
        lambda_value (float): Параметр регуляризации.

    Возвращает:
        loss (float): Значение функции потерь.
    """

    loss = -np.mean(b * np.log(sigmoid(A @ x)) + (1 - b) * np.log(1 - sigmoid(A @ x))) + lambda_value / 2 * np.sum(
        x ** 2)

    return loss


def grad(x, A=A_train, b=b_train, lambda_value=L / 1000):
    """
    Вычисляет градиент функции потерь.

    Параметры:
        x (np.array): Вектор параметров модели.
        A (np.array): Матрица признаков обучающей выборки.
        b (np.array): Вектор меток обучающей выборки.
        lambda_value (float): Параметр регуляризации.

    Возвращает:
        loss (np.array): Градиент функции потерь.
    """
    n = A_train.shape[0]
    gradient = 1 / n * (2 * A_train.T @ (A_train @ x - b_train)) + 2 * lambda_value * x

    return gradient


def hess(x, A=A_train, b=b_train, lambda_value=L / 1000):
    """
    Вычисляет гессиан функции потерь.

    Параметры:
        x (np.array): Вектор параметров модели
        A (np.array): Матрица признаков обучающей выборки
        b (np.array): Вектор меток обучающей выборки
        lambda_value (float): Параметр регуляризации

    Возвращает:
        hess (np.array): Гессиан функции потерь.
    """

    g = sigmoid(A @ x)
    D = g * (1 - g)
    n = A.shape[0]
    _hess = (1 / n) * A.T @ np.diag(D) @ A + lambda_value * np.eye(A.shape[1])
    return _hess

# %% [markdown]
# __а) (1 балл)__ Покажите, что для симплекса:
#
# $$
# \mathcal{X} = \left\{ s \in \mathbb{R}^d \mid s \succeq 0,~ \boldsymbol{1}^\top s = R \right\}
# $$
#
# решение LMO:
#
# $$
# s^* = R e_i,~ \text{где}~ i = \arg \min_{j = \overline{1, d}} c_j.
# $$

# %% [markdown]
# *Доказательство. (см. Утверждение Л9.8)* Запишем лагранжиан:
#
# $$
# \mathcal{L}(s, \lambda, \nu) = \langle s, c \rangle - \lambda^\top s - \nu \left( 1^\top s - R \right).
# $$
#
# Воспользуемся теоремой Каруша–Куна–Таккера (Теорема C8.1):
#
# 1. Ограничения: $ s \succeq 0, \; 1^\top s = R; $
# 2. Неотрицательность: $ \lambda \succeq 0; $
# 3. Дополняющая нежёсткость: $ \lambda_i s_i = 0; $
# 4. Стационарность: $ c - \lambda - \nu = 0. $
#
# Возьмём
#
# $$
# s^* = R e_i, \quad \lambda_j = c_j - c_i, \quad \nu = -c_i,
# $$
# где
# $$
# i = \operatorname{argmin}_{j=1,\ldots,d} c_j.
# $$

# %%
def lmo_simplex(g, R):
    """
    LMO для симплекса.

    Параметры:
        g (np.array): Градиент в текущей точке
        R (float): Размер симплекса

    Возвращает:
        s (np.array): LMO
    """
    e = np.zeros_like(g)
    e[np.argmin(g, axis=0)] = 1
    s = R * e

    return s

# %%
def tracking_error_variance(r_p, r_b):
    r_p = np.asarray(r_p)
    r_b = np.asarray(r_b)
    assert r_p.shape == r_b.shape

    diff = r_p - r_b
    T = len(diff)
    if T <= 1:
        return np.nan
    tev = (1.0 / (T - 1)) * np.sum(diff ** 2)
    return tev


def tracking_difference(r_p, r_b):
    r_p = np.asarray(r_p)
    r_b = np.asarray(r_b)
    assert r_p.shape == r_b.shape

    diff = r_p - r_b
    T = len(diff)
    if T == 0:
        return np.nan
    td = (1.0 / T) * np.sum(diff)
    return td


def portfolio_returns(A, w):
    A = np.asarray(A)
    w = np.asarray(w)
    return A @ w

# %%
def frank_wolfe(A, b, lambda_value, grad, lmo, x_0, eps=1e-8, max_iter=1000, **params):
    """
    Алгоритм Франк-Вульфа.

    Параметры:
        A (np.array): Матрица признаков.
        b (np.array): Вектор целевых значений
        lambda_value (float): Параметр регуляризации
        grad (Callable): Функция вычисления градиента
        lmo (Callable): Функция вычисления LMO
        x_0 (np.array): Начальная точка
        eps (float): Точность сходимости
        max_iter (int): Максимальное количество итераций
        params : Именованные гиперпараметры метода
            params['gamma'](k) : шаг на k-ой итерации
            params['R'] : радиус множества

    Возвращает:
        x_k (np.array) : Найденное решение
        history (list) : История метрики и значения
    """
    x_k = x_0.copy()
    history = {
        'values': [],
        'norms': [],
        'gaps': [],
        'gaps_averaged': [],
        'times': [],
        'k_assets': [],
        'tev': [],
        'td': [],
        'tev_test': [],
        'td_test': []
    }
    gaps_sum = 0.0
    start_time = time.time()

    for k in range(max_iter):
        g_k = grad(x_k)
        s = lmo(g_k, params['R'])

        gap_k = g_k @ (x_k - s)
        history['values'].append(loss(x_k, A, b, lambda_value))
        history['norms'].append(np.linalg.norm(g_k))
        history['gaps'].append(gap_k)
        gaps_sum += gap_k
        history['gaps_averaged'].append(gaps_sum / (k + 1))
        history['times'].append(time.time() - start_time)
        history['k_assets'].append(np.sum(x_k > 1e-5))

        r_p_train = portfolio_returns(A, x_k)
        r_b_train = b

        tev = tracking_error_variance(r_p_train, r_b_train)
        td = tracking_difference(r_p_train, r_b_train)
        history['tev'].append(tev)
        history['td'].append(td)


        r_p_test = portfolio_returns(A_test, x_k)
        r_b_test = b_test

        tev_test = tracking_error_variance(r_p_test, r_b_test)
        td_test = tracking_difference(r_p_test, r_b_test)
        history['tev_test'].append(tev_test)
        history['td_test'].append(td_test)

        if gap_k < eps:
            break

        x_k = (1 - params['gamma'](k)) * x_k + params['gamma'](k) * s

    return x_k, history

# %%
from matplotlib import pyplot as plt

N_ITER = 200
x_0 = np.zeros(X.shape[1])

final_w, hist = frank_wolfe(A=A_train, b=b_train, lambda_value=1 / L, grad=grad, lmo=lmo_simplex,
                            x_0=np.zeros(d_train), gamma=lambda k: 2 / (k + 2), R=1, eps=1e-18, A_test=A_test, b_test=b_test)

unique_k = sorted(list(set(hist['k_assets'])))
min_loss_per_k = []
min_loss_per_k_td = []

min_loss_per_k_test = []
min_loss_per_k_td_test = []

for k in unique_k:
    indices = [i for i, x in enumerate(hist['k_assets']) if x == k]
    tevs = [hist['tev'][i] for i in indices]
    tds = [hist['td'][i] for i in indices]
    tevs_test = [hist['tev_test'][i] for i in indices]
    tds_test = [hist['td_test'][i] for i in indices]

    min_loss_per_k.append(min(tevs))
    min_loss_per_k_td.append(min(tds))

    min_loss_per_k_test.append(min(tevs_test))
    min_loss_per_k_td_test.append(min(tds_test))

plt.figure(figsize=(10, 6))
plt.plot(unique_k, min_loss_per_k, marker='o', linestyle='-', label='TEV train')
plt.plot(unique_k, min_loss_per_k_test, marker='o', linestyle='-', label='TEV test')
plt.title("Sparsity Frontier: TEV vs Number of Assets")
plt.xlabel("Number of Assets (k)")
plt.ylabel("Metric (Tracking Error Variance )")
plt.grid(True)
plt.legend()
plt.yscale('log')
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(unique_k, min_loss_per_k_td, marker='o', linestyle='-', label='TD train')
plt.plot(unique_k, min_loss_per_k_td_test, marker='o', linestyle='-', label='TD test')
plt.title("Sparsity Frontier: TD vs Number of Assets")
plt.xlabel("Number of Assets (k)")
plt.ylabel("Metric (Tracking Difference)")
plt.grid(True)
plt.legend()
# plt.yscale('log')
plt.show()


print("Top efficient points (k vs Loss):")
for k, l in zip(unique_k[:15], min_loss_per_k[:15]):
    print(f"k={k}: Loss={l:.6f}")
# Out:
# Top efficient points (k vs Loss):
# k=0: Loss=0.000596
# k=1: Loss=0.233290
# k=2: Loss=0.026335
# k=3: Loss=0.007118
# k=4: Loss=0.002580
# k=5: Loss=0.001304
# k=6: Loss=0.000702
# k=7: Loss=0.000419
# k=8: Loss=0.000265
# k=9: Loss=0.000195
# k=10: Loss=0.000175
# k=11: Loss=0.000134
# k=12: Loss=0.000140
# k=13: Loss=0.000105
# k=14: Loss=0.000082

# %%
benchmark_returns = R_B.values.flatten()

portfolio_returns = (R_assets.values @ final_w).flatten()

def get_summary_stats(returns, name):
    return {
        'Series': name,
        'Mean': np.mean(returns),
        'Median': np.median(returns),
        'Std Dev': np.std(returns),
        'Variance': np.var(returns),
        'Min': np.min(returns),
        'Max': np.max(returns),
    }

stats_bench = get_summary_stats(benchmark_returns, 'FTSE 100 Index')
stats_port = get_summary_stats(portfolio_returns, 'Tracking Portfolio')

df_stats = pd.DataFrame([stats_bench, stats_port])


df_stats = df_stats.round(6)

latex_table = df_stats.to_latex(
    index=False,
    caption="Summary Statistics of Weekly Returns: FTSE 100 vs Tracking Portfolio",
    label="tab:summary_stats",
    column_format="lcccccc"
)

print(latex_table)
# Out:
# \begin{table}
# \caption{Summary Statistics of Weekly Returns: FTSE 100 vs Tracking Portfolio}
# \label{tab:summary_stats}
# \begin{tabular}{lcccccc}
# \toprule
# Series & Mean & Median & Std Dev & Variance & Min & Max \\
# \midrule
# FTSE 100 Index & 0.000538 & 0.001946 & 0.023225 & 0.000539 & -0.210469 & 0.134092 \\
# Tracking Portfolio & 0.001303 & 0.002326 & 0.023041 & 0.000531 & -0.203871 & 0.128261 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
import numpy as np
import matplotlib.pyplot as plt

index_returns = R_B.values

portfolio_returns = (R_assets.values @ final_w).flatten()

cum_index = np.cumprod(1 + index_returns) - 1
cum_portfolio = np.cumprod(1 + portfolio_returns) - 1

dates = R_B.index


plt.figure(figsize=(12, 6))
plt.plot(dates, cum_index * 100, label='FTSE 100 Index', linewidth=2, alpha=0.85)
plt.plot(dates, cum_portfolio * 100, label='Tracking Portfolio', linewidth=2, linestyle='--', alpha=0.85)

plt.title('Cumulative Returns: FTSE 100 vs Tracking Portfolio', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Cumulative Return (%)', fontsize=12)
plt.legend(fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.savefig('cumulative_returns.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd

weights_df = pd.DataFrame({
    'Ticker': R_assets.columns,
    'Weight': final_w
})

active_weights = weights_df[weights_df['Weight'] > 1e-4].sort_values('Weight', ascending=False)


top_10_numeric = active_weights.head(10).copy()
other_weight = active_weights.iloc[10:]['Weight'].sum()

if other_weight > 0:
    top_10_numeric = pd.concat([top_10_numeric, pd.DataFrame({'Ticker': ['Other'], 'Weight': [other_weight]})])

import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))
plt.pie(
    top_10_numeric['Weight'],
    labels=top_10_numeric['Ticker'],
    autopct='%1.1f%%',
    startangle=140
)
plt.title('Portfolio Allocation')
plt.savefig('portfolio_composition.png', dpi=300, bbox_inches='tight')
plt.show()

top_10_latex = top_10_numeric.copy()
top_10_latex['Weight'] = top_10_latex['Weight'].apply(lambda x: f"{x*100:.2f}\\%")

print(top_10_latex.to_latex(index=False, caption="Portfolio Composition", label="tab:portfolio_holdings"))
# Out:
# \begin{table}
# \caption{Portfolio Composition}
# \label{tab:portfolio_holdings}
# \begin{tabular}{ll}
# \toprule
# Ticker & Weight \\
# \midrule
# BP & 8.42\% \\
# VOD & 7.95\% \\
# GSK & 6.64\% \\
# HSBA & 6.30\% \\
# SMT & 5.15\% \\
# SHEL & 4.40\% \\
# AZN & 4.02\% \\
# REL & 3.35\% \\
# SGE & 3.34\% \\
# ALW & 2.78\% \\
# Other & 47.64\% \\
# \bottomrule
# \end{tabular}
# \end{table}
